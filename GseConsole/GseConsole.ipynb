# %%
# %run GseConsole.py -ipython
# %autocall 1
# Out:
# <h1>SoPhi IPython EGSE</h1><hr><p>Commands can be executed using <tt>gse()</tt> within IPython cell</p>
# Automatic calling is: Smart

# %%
gse 'boot dpu_software/SOPHI_DPU.bin'
# Out:
# ------> gse('boot dpu_software/SOPHI_DPU.bin')
# DPU will boot into: dpu_software/SOPHI_DPU.bin

# %%
gse 'reboot'
# Out:
# ------> gse('reboot')
# SO / PHI bootloader v1.0
# Booting into: dpu_software/SOPHI_DPU.bin
#  : 1008 @      fsFlashReport()]:NOR FLASH used 0 free: 0 in boot area 0 in nand fat area 0
